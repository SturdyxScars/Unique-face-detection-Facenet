# %%
import os

# %%
import tensorflow as tf

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.reduce_sum(tf.random.normal([1000, 1000])))
# Out:
# tf.Tensor(-377.7032, shape=(), dtype=float32)

# %%
os.environ["DEEPFACE_HOME"] = r"D:\conda_envs\retinaface"
from retinaface import RetinaFace
img_path = "11_Meeting_Meeting_11_Meeting_Meeting_11_174.jpg"
detect = RetinaFace.detect_faces(img_path=img_path)
print(detect)
# Out:
# {'face_1': {'score': 0.9998303651809692, 'facial_area': [706, 115, 826, 288], 'landmarks': {'right_eye': [720.89294, 175.78305], 'left_eye': [761.60736, 173.19939], 'nose': [717.33215, 196.53699], 'mouth_right': [716.1555, 233.64943], 'mouth_left': [757.29297, 231.38644]}}, 'face_2': {'score': 0.9992603659629822, 'facial_area': [262, 77, 376, 256], 'landmarks': {'right_eye': [350.3415, 154.8699], 'left_eye': [363.06934, 153.97049], 'nose': [375.10867, 190.61916], 'mouth_right': [328.4619, 212.81635], 'mouth_left': [341.50488, 213.86273]}}}

# %%
from PIL import Image
img = Image.open(img_path)

# %%
import cv2
image = cv2.imread(img_path)
for face in detect:
    
    cv2.circle(image, (x1,y1), 10, (255,0,0), 3)
    cv2.imshow('frame', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 image = cv2.imread(img_path)
#       3 for face in detect:
# ----> 4     x1, y1 = face['landmarks']['left_eye']
#       5     x2, y2 = face['landmarks']['right_eye']
#       6     cv2.circle(image, (x1,y1), 10, (255,0,0), 3)
#
# TypeError: string indices must be integers

# %%
for face in detect:
# Out:
# face_1
# face_2
